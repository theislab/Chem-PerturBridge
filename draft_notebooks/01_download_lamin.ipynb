# %%
#!pip3 install lamindb
#!pip3 install scanpy
#!pip3 install gcsfs
#!pip3 install rpy2
#!pip3 install anndata2ri
#!pip3 install decoupler
#!pip3 install pubchempy
#!pip3 install magnitude

# %%
import os
import lamindb as ln

# %%
def load_save_from_lamindb(key_adata: str,
                           key_obs: str, 
                           key_var: str,
                           path2adata: str,
                           path2obs: str,
                           path2var: str,
                           instance='laminlabs/pertdata'):
    '''
    
    '''
    ln.connect(instance)
    
    if not os.path.isfile(path2adata):
        dir_path = os.path.dirname(path2adata)
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)
            
        print('Download and save an anndata file...')
        ln.Artifact.get(key=key_adata).load().write_h5ad(path2adata, compression='gzip')
    else:
        print('An anndata file already exists')

    if not os.path.isfile(path2obs):
        dir_path = os.path.dirname(path2obs)
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)
            
        print('Download and save an .obs file...')
        ln.Artifact.get(key=key_obs).load().to_parquet(path2obs)
    else:
        print('An .obs file already exists')

    if not os.path.isfile(path2var):
        dir_path = os.path.dirname(path2var)
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)
            
        print('Download and save a .var file...')
        ln.Artifact.get(key=key_var).load().to_parquet(path2var)
    else:
        print('A .var file already exists')
    print('All data is saved')

# %% [markdown]
# ## Sciplex

# %%
key_adata = 'scperturb/srivatsan20_sciplex3.h5ad'
key_obs = 'scperturb/obs/srivatsan20_sciplex3.parquet'
key_var = 'scperturb/var/srivatsan20_sciplex3.parquet'
path2adata = '../data/Sciplex/lamin_processed/srivatsan20_sciplex3.h5ad'
path2obs = '../data/Sciplex/lamin_processed/srivatsan20_sciplex3_obs.parquet'
path2var = '../data/Sciplex/lamin_processed/srivatsan20_sciplex3_var.parquet'

load_save_from_lamindb(key_adata,
                       key_obs,
                       key_var,
                       path2adata,
                       path2obs,
                       path2var)
# Out:
# → connected lamindb: laminlabs/pertdata
# An anndata file already exists
# Download and save an .obs file...
# A .var file already exists
# All data is saved

# %% [markdown]
# ## Tahoe

# %%
key_adata = '2025-02-25/h5ad/plate1_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab.h5ad'
key_obs = 'tahoe100/obs/plate1.parquet'
key_var = 'tahoe100/var.parquet'
path2adata = '../data/Tahoe/lamin_processed/plate1_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab.h5ad'
path2obs = '../data/Tahoe/lamin_processed/plate1_obs.parquet'
path2var = '../data/Tahoe/lamin_processed/var.parquet'

load_save_from_lamindb(key_adata,
                       key_obs,
                       key_var,
                       path2adata,
                       path2obs,
                       path2var)
# Out:
# → connected lamindb: laminlabs/pertdata
# An anndata file already exists
# Download and save an .obs file...
# Download and save a .var file...
# All data is saved

# %%
key_adata = '2025-02-25/h5ad/plate2_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab.h5ad'
key_obs = 'tahoe100/obs/plate2.parquet'
key_var = 'tahoe100/var.parquet'
path2adata = '../data/Tahoe/lamin_processed/plate2_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab.h5ad'
path2obs = '../data/Tahoe/lamin_processed/plate2_obs.parquet'
path2var = '../data/Tahoe/lamin_processed/var.parquet'

load_save_from_lamindb(key_adata,
                       key_obs,
                       key_var,
                       path2adata,
                       path2obs,
                       path2var)
# Out:
# → connected lamindb: laminlabs/pertdata
# An anndata file already exists
# Download and save an .obs file...
# A .var file already exists
# All data is saved

# %%
#print(1)
