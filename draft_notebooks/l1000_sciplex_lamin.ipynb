# %%
print(1)
# Out:
# 1

# %%
import lamindb as ln

# %%
ln.connect("laminlabs/pertdata")
# Out:
# → the database (1.12.1) is ahead of your installed lamindb package (1.10.0)
# → consider updating lamindb: pip install lamindb>=1.12
# → connected lamindb: laminlabs/pertdata

# %%
adata = ln.Artifact.get(key='lincs/phase2/Level2_GEX_all_n537590x978.h5ad').load(mute=True)

# %%
sci_obs = ln.Artifact.get(key='scperturb/obs/srivatsan20_sciplex3.parquet').load(mute=True)

# %%
sci_var = ln.Artifact.get(key='scperturb/var/srivatsan20_sciplex3.parquet').load(mute=True)

# %%
adata.obs
# Out:
#          cell_id                   det_plate det_well             pert_mfc_id  \
# 0           A375      LJP005_A375_24H_X1_B19      A03                    dmso
# 1           A375      LJP005_A375_24H_X1_B19      A04                    dmso
# 2           A375      LJP005_A375_24H_X1_B19      A05                    dmso
# 3           A375      LJP005_A375_24H_X1_B19      A06                    dmso
# 4           A375      LJP005_A375_24H_X1_B19      A07  BRD-K76908866-001-06-8
# ...          ...                         ...      ...                     ...
# 537585  YAPC.311  XPR002_YAPC.311_96H_X3_B22      P20          BRDN0000585533
# 537586  YAPC.311  XPR002_YAPC.311_96H_X3_B22      P21          BRDN0000990361
# 537587  YAPC.311  XPR002_YAPC.311_96H_X3_B22      P22          BRDN0000735497
# 537588  YAPC.311  XPR002_YAPC.311_96H_X3_B22      P23          BRDN0000733798
# 537589  YAPC.311  XPR002_YAPC.311_96H_X3_B22      P24          BRDN0000735629
#
# ...

# %%
sci_obs
# Out:
#                                        pert_target        pert_compound  \
# A01_E09_RT_BC_100_Lig_BC_147                Aurora              TAK-901
# A01_E09_RT_BC_100_Lig_BC_186                  EGFR               AG-490
# A01_E09_RT_BC_100_Lig_BC_196                  HDAC          abexinostat
# A01_E09_RT_BC_100_Lig_BC_213                Aurora            alisertib
# A01_E09_RT_BC_100_Lig_BC_220                   DNA             busulfan
# ...                                            ...                  ...
# H12_F10_RT_BC_9_Lig_BC_237    Src,Sirtuin,PKC,PI3K            quercetin
# H12_F10_RT_BC_9_Lig_BC_274                Androgen             Andarine
# H12_F10_RT_BC_9_Lig_BC_291                    PARP             Iniparib
# H12_F10_RT_BC_9_Lig_BC_298                     PKC  Bisindolylmaleimide
# H12_F10_RT_BC_9_Lig_BC_4                       NaN                  NaN
#
#                               pert_dose pert_time organism cell_line  \
# ...

# %%
adata.var
# Out:
#                     rid pr_analyte_id  pr_analyte_num pr_bset_id pr_lua_id  \
# pr_gene_id
# 5720          200814_at    Analyte 11              11       dp52  LUA-3404
# 55847       218597_s_at    Analyte 12              12       dp52  LUA-3431
# 7416        217140_s_at    Analyte 12              12       dp53  LUA-4000
# 10174         209253_at    Analyte 13              13       dp53  LUA-4040
# 25803       214404_x_at    Analyte 13              13       dp52  LUA-1326
# ...                 ...           ...             ...        ...       ...
# 10153         203341_at   Analyte 498             498       dp53   LUA-876
# 5566          202801_at   Analyte 498             498       dp52    LUA-81
# 2597        217398_x_at   Analyte 499             499       dp53   LUA-576
# 874           205379_at   Analyte 500             500       dp53  LUA-4022
# 57149         203897_at   Analyte 500             500       dp52   LUA-589
#
#            pr_pool_id pr_gene_symbol  \
# pr_gene_id
# ...

# %%
sci_var
# Out:
#                       symbol
# ensembl_id
# ENSG00000000003       TSPAN6
# ENSG00000000005         TNMD
# ENSG00000000419         DPM1
# ENSG00000000457        SCYL3
# ENSG00000000460     C1orf112
# ...                      ...
# ENSG00000284744   AL591163.1
# ENSG00000284745   AL589702.1
# ENSG00000284746  AC068587.10
# ENSG00000284747   AL034417.4
# ENSG00000284748   AL513220.1
#
# [58302 rows x 1 columns]
