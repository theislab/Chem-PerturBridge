# %%
library(dplyr, warn.conflicts = FALSE)
library(tidyr, warn.conflicts = FALSE)
library(purrr, warn.conflicts = FALSE)
library(tibble, warn.conflicts = FALSE)
#library(furrr)
library(future)
library(readr)
library(edgeR)
library(limma)
library(dplyr)
library(statmod)
library(data.table)
library(arrow)

# %%
# Function to convert drug names to valid R variable names
make_valid_names <- function(names_vector) {
  # Replace invalid characters with underscores
  valid_names <- gsub("[^[:alnum:]_]", "_", names_vector)
  
  # Ensure the names start with a letter (required for R variable names)
  valid_names <- make.names(valid_names)
  
  return(valid_names)
}

# %%
# Function to clean the column names
clean_column_names <- function(names_vector) {
  # Remove "factor(valid_drug_names)X" prefix
  cleaned_names <- gsub("^factor\\(valid_drug_names\\)X", "", names_vector)
  
  # Replace multiple underscores with a single underscore
  cleaned_names <- gsub("_+", "_", cleaned_names)
  
  return(cleaned_names)
}

# %%
# Function to clean the column names
clean_contrast_names <- function(names_vector) {
  # Remove leading underscores (or other unwanted characters) and clean the names
  cleaned_names <- gsub("^_", "", names_vector)  # Remove leading underscores
  cleaned_names <- make.names(cleaned_names)  # Ensure valid R names
  
  # Optionally, remove additional unwanted characters if needed
  cleaned_names <- gsub("[^[:alnum:]_]", "_", cleaned_names)  # Replace non-alphanumeric characters with underscores
  
  return(cleaned_names)
}

# %%
# Set the path to your folder
folder_path <- "/lustre/groups/ml01/workspace/manuel.gander/data/prelimma/mD3"

# Get all files in the folder
files <- list.files(path = folder_path, full.names = TRUE)
sample_names <- sub(".*/(.*)_.*\\.csv", "\\1", files)
celllines = sort(unique(unname(sample_names)))
celllines
# Out:
#  [1] "A172"      "A427"      "A498"      "A549"      "AN3CA"     "AsPC1"
#  [7] "BT474"     "C32"       "C33A"      "CFPAC1"    "CHP212"    "COLO205"
# [13] "H4"        "HCT15"     "HEC1A"     "HepG2C3A"  "HOP62"     "HS578T"
# [19] "Hs766T"    "HT29"      "hTERTHPNE" "J82"       "KATOIII"   "LoVo"
# [25] "LOXIMVI"   "LS180"     "MIAPaCa2"  "NCIH1573"  "NCIH1792"  "NCIH2030"
# [31] "NCIH2122"  "NCIH23"    "NCIH2347"  "NCIH460"   "NCIH596"   "NCIH661"
# [37] "Panc0327"  "PANC1"     "RKO"       "RPMI7951"  "SHP77"     "SKMEL2"
# [43] "SNU1"      "SNU423"    "SW1088"    "SW1271"    "SW1417"    "SW48"
# [49] "SW480"     "SW900"

# %%
for (cellline in celllines[1:10]){
    tryCatch({
    file0 = '/lustre/groups/ml01/workspace/manuel.gander/data/prelimma/mD3/'
    path = paste0(file0, cellline)

    X <- as.matrix(fread(paste0(path, "_X.csv"), header = FALSE, skip = 1))
    var <- read_csv(paste0(path, "_var.csv"))
    obs <- read_csv(paste0(path, "_obs.csv"))

    valid_drug_names <- make_valid_names(obs$drugname_drugconc)
    plate <- factor(obs$plate)

    # Create the design matrix based on the cell types
    design_matrix <- model.matrix(~ 0 + factor(valid_drug_names) + plate)
    colnames(design_matrix) <- clean_column_names(colnames(design_matrix))
    colnames(design_matrix) <- clean_contrast_names(colnames(design_matrix))


    # Create DGEList object
    d0 <- DGEList(counts = t(X))
    keep_genes <- filterByExpr(d0, design = design_matrix)
    d0 <- d0[keep_genes, , keep.lib.sizes = FALSE]
    d0 <- calcNormFactors(d0)

    # Perform the Voom transformation and fit the model
    v <- voom(d0, design = design_matrix, plot = FALSE)
    fit <- lmFit(v, design_matrix)

    # Output the results
    summary(fit)

    # get proper DMSO name
    conditions <- setdiff(unique(colnames(design_matrix)), "DMSO_TF_0_0_uM_")

    # Initialize a list to store results
    de_results_list <- list()

    # Loop through conditions
    for (condition in conditions) {
        cat("Doing condition", condition, "\n")
        flush.console()  # Force the output to be printed immediately
        # Create contrast formula
        contrast_formula <- paste0(condition, " - ", "DMSO_TF_0_0_uM_")
        contr <- makeContrasts(contrasts = contrast_formula, levels = colnames(design_matrix))

        # Fit the contrast and apply eBayes
        contrast_fit <- contrasts.fit(fit, contr)
        contrast_fit <- eBayes(contrast_fit, robust = TRUE)

        # Get the top table of results
        top_table <- topTable(contrast_fit, number = Inf, sort.by = "none", adjust.method = "BH")
        rownames(top_table) <- var$aa[keep_genes]

        # Add additional metadata
        top_table$gene <- rownames(top_table)
        top_table$condition <- condition
        top_table$control_type <- "[('DMSO_TF', 0.0, 'uM')]"
        top_table$cellline <- cellline

        # Store in list (only if significant)
        if(nrow(top_table) > 0) {
            de_results_list[[condition]] <- top_table
        }
    }

    de_results_combined <- do.call(rbind, de_results_list)

    output_file <- paste0("/lustre/groups/ml01/workspace/manuel.gander/data/postlimma/mDf3/", 
        cellline, "_conditions.parquet")
    write_parquet(tibble(condition = conditions), output_file)


    output_file <- paste0("/lustre/groups/ml01/workspace/manuel.gander/data/postlimma/mDf3/", 
        cellline, "_differential_expression_results.parquet")
    write_parquet(de_results_combined, output_file)
    
    })
}
# Out:
# Rows: 62710 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): gene_name
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1334 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (5): BARCODE_SUB_LIB_ID, sample, cell_name, bc1_well, drugname_drugconc
# dbl (2): n_cells, plate
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Doing condition X1_4EGI_1_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_9_ING_41_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Adagrasib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Afatinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Alpelisib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Anastrozole_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_APTO_253_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_AT7519_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_AZD_7648_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_AZD_8055_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_AZD1390_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_AZD2858_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_BAY1125976_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Belumosudil_mesylate_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Bentamapimod_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_BI_3406_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_BI_78D3_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Bimiralisib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Binimetinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Bortezomib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Brivudine_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_c_Kit_IN_1_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Capivasertib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Capmatinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Celecoxib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_CP21R7_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Dabrafenib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_DT_061_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Elimusertib_hydrochloride_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Encorafenib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Erdafitinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_ERK5_IN_2_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_ETC_206_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Everolimus_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_EX229_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Futibatinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Gemcitabine_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_GSK1059615_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_HI_TOPK_032_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Hydroxyfasudil_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Infigratinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Ipatasertib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_IQ_1_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Irinotecan_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Ixazomib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Lapatinib_ditosylate_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_LB_100_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_LJI308_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Lonafarnib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_LY_2584702_tosylate_salt_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_LY2090314_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Minodronic_acid_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_MK_3903_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_MK_8353_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_ML264_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_NG25_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_NVP_BHG712_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_olaparib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Oleic_acid_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_OTS514_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Oxaliplatin_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Paclitaxel_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_palbociclib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Pemigatinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_PH_797804_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Pimitespib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Pralsetinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Regorafenib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_RMC_6236_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Sapanisertib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_SBI_0640756_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Sonidegib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_TAK_733_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_TAK_901_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Temuterkib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Tomivosertib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Torkinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Trametinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Tubulin_inhibitor_6_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Tucatinib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_ULK_101_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Vemurafenib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_venetoclax_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_vincristine_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_Volasertib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X1_XRK3F2_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_5_Azacytidine_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_5_Fluorouracil_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Abiraterone_acetate_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Acetazolamide_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Adagrasib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Allopurinol_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Aprepitant_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Artemether_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Asciminib_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Aspirin_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Ataluren_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_Atazanavir_sulfate_0_05_uM_
# Warning message:
# “Unknown or uninitialised column: `aa`.”
# Doing condition X10_